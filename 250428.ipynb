# %% [markdown]
# <a href="https://colab.research.google.com/github/krispy11tw/250416/blob/main/250428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req

url = "https://github.com/Elwing-Chou/tibame_online_0416/raw/refs/heads/main/tabelog%20(3).csv"
req.urlretrieve(url, "tabelog.csv")
# Out:
# ('tabelog.csv', <http.client.HTTPMessage at 0x7a397e8d3ed0>)

# %%
import pandas as pd
df = pd.read_csv("tabelog.csv", encoding="utf-8", index_col=0)
df
# Out:
#        評分                      店名  \
# 0    4.03                       6
# 1    3.93                   BACAR
# 2    3.78  Shunsai Dokoro Biidoro
# 3    3.77        Grand Bleu Gamin
# 4    3.75              Niima Soba
# ..    ...                     ...
# 195  3.56            Onna Shokudo
# 196  3.56   La Maison Claire 1853
# 197  3.56                 Ibukuro
# 198  3.56      kawamitsu shokudou
# 199  3.56      Miyahira Ryori Ten
#
#                                                     連結      地點  \
# 0    https://tabelog.com/tw/okinawa/A4702/A470202/4...     NaN
# 1    https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 2    https://tabelog.com/tw/okinawa/A4701/A470101/4...   美榮橋車站
# 3    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# 4    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# ..                                                 ...     ...
# 195  https://tabelog.com/tw/okinawa/A4703/A470303/4...     NaN
# 196  https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 197  https://tabelog.com/tw/okinawa/A4704/A470403/4...     NaN
# 198  https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# 199  https://tabelog.com/tw/okinawa/A4703/A470404/4...     NaN
#
#                     類型                   晚餐價格                   午餐價格      休息日
# 0             創新, 法式料理  JPY 20,000～JPY 29,999  JPY 10,000～JPY 14,999        -
# 1            披薩, 義大利料理  JPY 15,000～JPY 19,999                      -  星期一、星期日
# 2    日式小酒館, 沖繩料理, 創作料理    JPY 3,000～JPY 3,999                      -  星期一、星期日
# 3     法式料理, 鐵板燒, 旅館/酒店  JPY 15,000～JPY 19,999    JPY 4,000～JPY 4,999        -
# 4                  沖繩麵               ～JPY 999               ～JPY 999      星期四
# ..                 ...                    ...                    ...      ...
# 195              法式小酒館    JPY 8,000～JPY 9,999                      -        -
# 196        法式料理, 法式小酒館    JPY 8,000～JPY 9,999    JPY 2,000～JPY 2,999      星期日
# 197               創作料理  JPY 10,000～JPY 14,999                      -  星期一、星期二
# 198           食堂, 沖繩料理    JPY 5,000～JPY 5,999    JPY 2,000～JPY 2,999      星期一
# 199              法式小酒館    JPY 5,000～JPY 5,999                      -  星期三、星期日
#
# [200 rows x 8 columns]

# %%
# 上次的!!!
def func(score):
    return round(score * 2, 1)
df["評分"].apply(func)

# %%
# 我要變成七個行(禮拜一open: Y/N)
# pandas: DataFrame(表格)(2D)  Series(行/列)(1D)
# 如果你想把值擴充(多個欄位): return Series
def func(s):
    open_days = {
        "星期一":"Y",
        "星期二":"Y",
        "星期三":"Y",
        "星期四":"Y",
        "星期五":"Y",
        "星期六":"Y",
        "星期日":"Y",
    }
    for spl in s.split("、"):
        if spl in open_days:
            open_days[spl] = "N"
    return pd.Series(open_days)

# 方法1: df[["星期一","星期二","星期三"...]] = 轉換
# pandas的功能大部分都有一個參數 axis 只有兩種值 0/1 剛好代表兩種方向
convert = df["休息日"].apply(func)
df = pd.concat([df, convert], axis=1)
df
# Out:
#        評分                      店名  \
# 0    4.03                       6
# 1    3.93                   BACAR
# 2    3.78  Shunsai Dokoro Biidoro
# 3    3.77        Grand Bleu Gamin
# 4    3.75              Niima Soba
# ..    ...                     ...
# 195  3.56            Onna Shokudo
# 196  3.56   La Maison Claire 1853
# 197  3.56                 Ibukuro
# 198  3.56      kawamitsu shokudou
# 199  3.56      Miyahira Ryori Ten
#
#                                                     連結      地點  \
# 0    https://tabelog.com/tw/okinawa/A4702/A470202/4...     NaN
# 1    https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 2    https://tabelog.com/tw/okinawa/A4701/A470101/4...   美榮橋車站
# 3    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# 4    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# ..                                                 ...     ...
# 195  https://tabelog.com/tw/okinawa/A4703/A470303/4...     NaN
# 196  https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 197  https://tabelog.com/tw/okinawa/A4704/A470403/4...     NaN
# 198  https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# 199  https://tabelog.com/tw/okinawa/A4703/A470404/4...     NaN
#
#                     類型                   晚餐價格                   午餐價格      休息日  \
# 0             創新, 法式料理  JPY 20,000～JPY 29,999  JPY 10,000～JPY 14,999        -
# 1            披薩, 義大利料理  JPY 15,000～JPY 19,999                      -  星期一、星期日
# 2    日式小酒館, 沖繩料理, 創作料理    JPY 3,000～JPY 3,999                      -  星期一、星期日
# 3     法式料理, 鐵板燒, 旅館/酒店  JPY 15,000～JPY 19,999    JPY 4,000～JPY 4,999        -
# 4                  沖繩麵               ～JPY 999               ～JPY 999      星期四
# ..                 ...                    ...                    ...      ...
# 195              法式小酒館    JPY 8,000～JPY 9,999                      -        -
# 196        法式料理, 法式小酒館    JPY 8,000～JPY 9,999    JPY 2,000～JPY 2,999      星期日
# 197               創作料理  JPY 10,000～JPY 14,999                      -  星期一、星期二
# 198           食堂, 沖繩料理    JPY 5,000～JPY 5,999    JPY 2,000～JPY 2,999      星期一
# 199              法式小酒館    JPY 5,000～JPY 5,999                      -  星期三、星期日
#
#     星期一 星期二 星期三 星期四 星期五 星期六 星期日
# 0     Y   Y   Y   Y   Y   Y   Y
# 1     N   Y   Y   Y   Y   Y   N
# 2     N   Y   Y   Y   Y   Y   N
# 3     Y   Y   Y   Y   Y   Y   Y
# 4     Y   Y   Y   N   Y   Y   Y
# ..   ..  ..  ..  ..  ..  ..  ..
# 195   Y   Y   Y   Y   Y   Y   Y
# 196   Y   Y   Y   Y   Y   Y   N
# 197   N   N   Y   Y   Y   Y   Y
# 198   N   Y   Y   Y   Y   Y   Y
# 199   Y   Y   N   Y   Y   Y   N
#
# [200 rows x 15 columns]

# %%
# 過濾: 帶入跟你資料筆數一樣多的True/False
query_day = "星期三"
fil = df[query_day] == "Y"
df[fil]
# Out:
#        評分                      店名  \
# 0    4.03                       6
# 1    3.93                   BACAR
# 2    3.78  Shunsai Dokoro Biidoro
# 3    3.77        Grand Bleu Gamin
# 4    3.75              Niima Soba
# ..    ...                     ...
# 194  3.56      SPICE HERB HOLIDAY
# 195  3.56            Onna Shokudo
# 196  3.56   La Maison Claire 1853
# 197  3.56                 Ibukuro
# 198  3.56      kawamitsu shokudou
#
#                                                     連結      地點  \
# 0    https://tabelog.com/tw/okinawa/A4702/A470202/4...     NaN
# 1    https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 2    https://tabelog.com/tw/okinawa/A4701/A470101/4...   美榮橋車站
# 3    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# 4    https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
# ..                                                 ...     ...
# 194  https://tabelog.com/tw/okinawa/A4701/A470101/4...   美榮橋車站
# 195  https://tabelog.com/tw/okinawa/A4703/A470303/4...     NaN
# 196  https://tabelog.com/tw/okinawa/A4701/A470101/4...  縣政府前車站
# 197  https://tabelog.com/tw/okinawa/A4704/A470403/4...     NaN
# 198  https://tabelog.com/tw/okinawa/A4705/A470503/4...     NaN
#
#                     類型                   晚餐價格                   午餐價格      休息日  \
# 0             創新, 法式料理  JPY 20,000～JPY 29,999  JPY 10,000～JPY 14,999        -
# 1            披薩, 義大利料理  JPY 15,000～JPY 19,999                      -  星期一、星期日
# 2    日式小酒館, 沖繩料理, 創作料理    JPY 3,000～JPY 3,999                      -  星期一、星期日
# 3     法式料理, 鐵板燒, 旅館/酒店  JPY 15,000～JPY 19,999    JPY 4,000～JPY 4,999        -
# 4                  沖繩麵               ～JPY 999               ～JPY 999      星期四
# ..                 ...                    ...                    ...      ...
# 194               泰式料理    JPY 2,000～JPY 2,999                      -      星期日
# 195              法式小酒館    JPY 8,000～JPY 9,999                      -        -
# 196        法式料理, 法式小酒館    JPY 8,000～JPY 9,999    JPY 2,000～JPY 2,999      星期日
# 197               創作料理  JPY 10,000～JPY 14,999                      -  星期一、星期二
# 198           食堂, 沖繩料理    JPY 5,000～JPY 5,999    JPY 2,000～JPY 2,999      星期一
#
#     星期一 星期二 星期三 星期四 星期五 星期六 星期日
# 0     Y   Y   Y   Y   Y   Y   Y
# 1     N   Y   Y   Y   Y   Y   N
# 2     N   Y   Y   Y   Y   Y   N
# 3     Y   Y   Y   Y   Y   Y   Y
# 4     Y   Y   Y   N   Y   Y   Y
# ..   ..  ..  ..  ..  ..  ..  ..
# 194   Y   Y   Y   Y   Y   Y   N
# 195   Y   Y   Y   Y   Y   Y   Y
# 196   Y   Y   Y   Y   Y   Y   N
# 197   N   N   Y   Y   Y   Y   Y
# 198   N   Y   Y   Y   Y   Y   Y
#
# [173 rows x 15 columns]

# %%
import urllib.request as req

url = "https://www.ptt.cc/bbs/Beauty/M.1745582404.A.011.html"
resp = req.urlopen(url)
resp.read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-bfe28bd1c270> in <cell line: 0>()
#       2
#       3 url = "https://www.ptt.cc/bbs/Beauty/M.1745582404.A.011.html"
# ----> 4 resp = req.urlopen(url)
#       5 resp.read()
#
# /usr/lib/python3.11/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.11/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.11/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.11/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.11/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.11/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# ```
# 下載圖片
# HTTP代碼:
# 1. 2開頭: 成功
# 2. 3開頭: 轉址(輸入舊網址, 帶你來到新的)
# 3. 4開頭: 錯誤
#     a. 404: Not Found(檢查網址)
#     b. 403: Forbidden
#         - 禁止ip(很多次以後)
#         - 你跟瀏覽器不一樣(!!!!)
#
# 一個網址(額外訊息: request headers)
# 一個回覆(額外訊息: response headers)
# ```

# %%
import json
import urllib.request as req
import bs4 as bs

url = "https://www.ptt.cc/bbs/Beauty/M.1745582404.A.011.html"
r = req.Request(url)
r.add_header("User-Agent", "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0")
resp = req.urlopen(r)
html = bs.BeautifulSoup(resp.read())

# 作者/看版/標題/日期
metas = html.find_all("span", {"class":"article-meta-value"})
uid_text = metas[0].text
board_text = metas[1].text
title_text = metas[2].text
time_text = metas[3].text
# print(uid_text, board_text, title_text, time_text, sep="\n")


# 每個推虛文 [{"type":"", "id":"", "text":"", "date_ip":""}]
# JSON格式: {"作者": "看板": "標題": "推噓文":[]}
push_list = []
pushes = html.find_all("div", {"class":"push"})
for push in pushes:
    push_meta = push.find_all("span")
    # 推噓處理
    push_type_text = push_meta[0].text
    if "推" in push_type_text:
        push_type_text = 1
    elif "噓" in push_type_text:
        push_type_text = -1
    else:
        push_type_text = 0
    # 推噓id
    push_id_text = push_meta[1].text
    # 推噓內容
    push_content_text = push_meta[2].text.replace(": ", "")
    # 推噓ipdate
    push_ipdate_text = push_meta[3].text.strip()
    # print(push_type_text, push_id_text, push_content_text, push_ipdate_text, sep="\t")
    push_data = {
        "type":push_type_text,
        "id":push_id_text,
        "text":push_content_text,
        "date_ip":push_ipdate_text
    }
    push_list.append(push_data)
# print(push_list)
post = {
    "作者":uid_text,
    "看板":board_text,
    "標題":title_text,
    "日期":time_text,
    "推噓文":push_list
}
# print(post)

#存檔
#檔名不要用標題存，容易亂碼(特殊符號)，用網址存
#附檔名不影響檔案內容
fn = url.split("/")[-1] + ".json"
#用with as操作存檔
with open(fn, "w", encoding="utf-8") as f:
    #ensure_ascii可以把預設英文編碼轉換
    json.dump(post, f, ensure_ascii=False, indent=4)
